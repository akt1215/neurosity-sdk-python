# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/workspaces/neurosity-sdk-python/Datas/demo3.csv')
data.describe()
# Out:
#                  A            B            C            D            E  \
# count  3832.000000  3832.000000  3832.000000  3832.000000  3832.000000
# mean     -0.114382    -0.190869    -0.162723    -0.030876     0.134134
# std      73.769675    73.846085    74.141018    74.582035    75.115244
# min    -907.544269  -919.703279  -926.745117  -932.451892  -982.375454
# 25%      -8.451967    -8.487166    -8.725567    -8.636459    -8.614324
# 50%      -0.122935    -0.304478    -0.305252    -0.269933    -0.023735
# 75%       7.841372     7.804728     7.726050     7.864611     8.055824
# max    1345.536287  1228.520070  1086.494970  1029.299362   997.307385
#
#                  F            G            H            I            J  \
# count  3832.000000  3832.000000  3832.000000  3832.000000  3832.000000
# mean      0.237498     0.213077     0.058948    -0.142462    -0.274324
# std      75.562668    75.744745    75.665586    75.419331    75.119152
# ...

# %%
plt.figure(figsize=(100,50))
plt.plot(data["A"], label="A")
plt.plot(data["B"], label="B")
plt.plot(data["C"], label="C")
plt.plot(data["D"], label="D")
plt.plot(data["E"], label="E")
plt.plot(data["F"], label="F")
plt.plot(data["G"], label="G")
plt.plot(data["H"], label="H")
plt.plot(data["I"], label="I")
plt.plot(data["J"], label="J")
plt.plot(data["K"], label="K")
plt.plot(data["L"], label="L")
plt.plot(data["M"], label="M")
plt.plot(data["N"], label="N")
plt.plot(data["O"], label="O")
plt.plot(data["P"], label="P")
plt.plot(data["Target"]*2000, label="Target")


plt.legend()
plt.show()
