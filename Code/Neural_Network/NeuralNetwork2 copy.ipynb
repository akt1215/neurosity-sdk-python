# %%
import pandas as pd
import numpy as np
import seaborn as sns
import keras
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
# Out:
# 2024-05-03 02:31:14.258700: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-03 02:31:14.261601: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-03 02:31:14.298624: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 02:31:15.263320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
base = pd.read_csv('/workspaces/neurosity-sdk-python/Datas/psd_base.csv')
grab = pd.read_csv('/workspaces/neurosity-sdk-python/Datas/psd_grab.csv')

# %%
# Make a new column with the sum of all the values in the row
base['Sum'] = base.sum(axis=1)/10
grab['Sum'] = grab.sum(axis=1)/10

# add values to the "target" column. The number should be 0
base['target'] = 0
grab['target'] = 1

# %%
# Merge the data
data = pd.concat([base, grab], axis=0)
#shuffle the data
data = data.sample(frac=1)
data.describe()
# Out:
#                 D1           D2           D3           D4           D5  \
# count  4528.000000  4528.000000  4528.000000  4528.000000  4528.000000
# mean      8.472433    14.180250    15.366889    10.566712     7.597573
# std      15.405903    23.499382    26.840364    20.318374    12.958813
# min       0.002180     0.093300     0.141388     0.040924     0.020230
# 25%       1.399696     2.905374     3.285515     2.392493     1.958046
# 50%       3.253131     5.670529     6.234385     4.556224     3.536193
# 75%       9.218818    15.218570    16.123836    10.794261     7.465556
# max     203.620997   251.156391   321.608539   355.108149   287.801974
#
#                 D6           D7           D8           D9          D10  ...  \
# count  4528.000000  4528.000000  4528.000000  4528.000000  4528.000000  ...
# mean      5.567881     4.302003     3.466977     2.968676     2.656601  ...
# std       8.136502     6.277514     4.551931     3.817952     3.249464  ...
# min       0.050707     0.015187     0.061742     0.019409     0.052823  ...
# 25%       1.768007     1.556438     1.207825     1.069599     0.981987  ...
# 50%       3.232155     2.738381     2.111210     1.864160     1.727479  ...
# 75%       5.932876     4.741065     3.833489     3.320360     3.019919  ...
# max     174.356546   183.005428    75.094336    95.929406    49.578123  ...
#
#                D57          D58          D59          D60          D61  \
# count  4528.000000  4528.000000  4528.000000  4528.000000  4528.000000
# mean      0.307544     0.305823     0.304803     0.303486     0.302863
# std       0.577548     0.565557     0.572646     0.561435     0.569189
# min       0.001001     0.000262     0.000692     0.000176     0.000383
# 25%       0.056166     0.052571     0.055609     0.052107     0.055218
# 50%       0.128436     0.123618     0.127113     0.122658     0.126216
# 75%       0.305454     0.306224     0.302747     0.303905     0.300889
# max      10.834435     8.062343    10.741666     8.003771    10.676163
#
#                D62          D63          D64          Sum       target
# count  4528.000000  4528.000000  4528.000000  4528.000000  4528.000000
# mean      0.301939     0.301704     0.301168    10.936065     0.524735
# std       0.558716     0.567135     0.557368    15.091951     0.499443
# min       0.000110     0.000215     0.000055     1.250945     0.000000
# 25%       0.051913     0.055022     0.051745     3.535792     0.000000
# 50%       0.122093     0.125615     0.121807     5.820246     1.000000
# 75%       0.302149     0.299769     0.301349    11.645471     1.000000
# max       7.965221    10.637227     7.945958   211.427345     1.000000
#
# [8 rows x 66 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(64, input_dim = X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

number_of_epochs = 60
model.fit(X_train, y_train, epochs=number_of_epochs, batch_size=5, validation_split=0.3)

plt.figure(figsize=(20, 10))
plt.scatter(range(number_of_epochs), model.history.history['accuracy'], s=30)
plt.scatter(range(number_of_epochs), model.history.history['val_accuracy'], s=30)
predictions = model.predict(X_test)
print("Accuracy: ", model.evaluate(X_test, y_test)[1])
print(predictions[:5])
print(y_test[:5])

model.save('model.keras')
# Out:
# Epoch 1/60
# /home/vscode/.local/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.
60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 937us/step - accuracy: 0.7276 - loss: 0.5146 - val_accuracy: 0.5823 - val_loss: 0.7371
# Epoch 35/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.7486 - loss: 0.4974 - val_accuracy: 0.5805 - val_loss: 0.7639
# Epoch 36/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.7301 - loss: 0.5042 - val_accuracy: 0.6053 - val_loss: 0.7482
# Epoch 37/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.7612 - loss: 0.4773 - val_accuracy: 0.5860 - val_loss: 0.7456
# Epoch 38/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - accuracy: 0.7684 - loss: 0.4848 - val_accuracy: 0.5833 - val_loss: 0.8183
# Epoch 39/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 928us/step - accuracy: 0.7383 - loss: 0.4891 - val_accuracy: 0.5750 - val_loss: 0.8205
# Epoch 40/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.7713 - loss: 0.4635 - val_accuracy: 0.5731 - val_loss: 0.7979
# Epoch 41/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.7651 - loss: 0.4671 - val_accuracy: 0.5879 - val_loss: 0.7964
# Epoch 42/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.7706 - loss: 0.4757 - val_accuracy: 0.5879 - val_loss: 0.8102
# Epoch 43/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 942us/step - accuracy: 0.7575 - loss: 0.4638 - val_accuracy: 0.5961 - val_loss: 0.7998
# Epoch 44/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.7807 - loss: 0.4452 - val_accuracy: 0.5777 - val_loss: 0.8455
# Epoch 45/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7999 - loss: 0.4149 - val_accuracy: 0.5768 - val_loss: 0.8641
# Epoch 46/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.8037 - loss: 0.4216 - val_accuracy: 0.5768 - val_loss: 0.8929
# Epoch 47/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.7865 - loss: 0.4284 - val_accuracy: 0.5741 - val_loss: 0.8458
# Epoch 48/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - accuracy: 0.8070 - loss: 0.4038 - val_accuracy: 0.5888 - val_loss: 0.9262
# Epoch 49/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.7882 - loss: 0.4238 - val_accuracy: 0.5833 - val_loss: 0.9029
# Epoch 50/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.8006 - loss: 0.4025 - val_accuracy: 0.5768 - val_loss: 0.9133
# Epoch 51/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 924us/step - accuracy: 0.8065 - loss: 0.3841 - val_accuracy: 0.5722 - val_loss: 0.9391
# Epoch 52/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.8242 - loss: 0.3829 - val_accuracy: 0.5731 - val_loss: 0.9570
# Epoch 53/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.8249 - loss: 0.3846 - val_accuracy: 0.5612 - val_loss: 1.0017
# Epoch 54/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - accuracy: 0.8118 - loss: 0.3933 - val_accuracy: 0.5722 - val_loss: 1.0204
# Epoch 55/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.8300 - loss: 0.3669 - val_accuracy: 0.5796 - val_loss: 1.0304
# Epoch 56/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.8040 - loss: 0.3929 - val_accuracy: 0.5823 - val_loss: 1.0398
# Epoch 57/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.8214 - loss: 0.3732 - val_accuracy: 0.5575 - val_loss: 1.0301
# Epoch 58/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.8451 - loss: 0.3526 - val_accuracy: 0.5575 - val_loss: 1.0613
# Epoch 59/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 1s 920us/step - accuracy: 0.8426 - loss: 0.3397 - val_accuracy: 0.5658 - val_loss: 1.1428
# Epoch 60/60
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.8362 - loss: 0.3469 - val_accuracy: 0.5667 - val_loss: 1.0596
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.6112 - loss: 0.9808
# Accuracy:  0.5894039869308472
# [[0.51415366]
#  [0.44219083]
#  [0.12678881]
#  [0.5225093 ]
#  [0.42765874]]
# 780     1
# 1608    1
# 395     0
# 1171    0
# 2068    1
# Name: target, dtype: int64

# %%
#import model.keras and test it
model = keras.models.load_model('model.keras')
model.evaluate(data.drop('target', axis=1), data["target"])
print("Accuracy", model.evaluate(data.drop('target', axis=1), data["target"])[1] * 100)
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.7147 - loss: 0.6632
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.7147 - loss: 0.6632
# Accuracy 72.15105891227722
